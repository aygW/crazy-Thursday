# %%
import ldav
import pyLDAvis
import pyLDAvis.gensim 

c, itw, dictionary= ldav.load_id2word_corpus('data_demo.csv')
lda_model = ldav.lda_vis(c, itw)
vis = pyLDAvis.gensim.prepare(lda_model, c, dictionary)
vis
# Out:
# [(0, '0.011*"双皮奶" + 0.008*"甜品" + 0.007*"广州" + 0.006*"传统" + 0.006*"他家" + 0.005*"不是" + 0.005*"尝试" + 0.005*"一定" + 0.005*"不错" + 0.004*"杨枝"'), (1, '0.013*"双皮奶" + 0.011*"甜品" + 0.010*"广州" + 0.009*"真的" + 0.008*"南信" + 0.007*"红豆" + 0.007*"好吃" + 0.007*"香芋" + 0.007*"没有" + 0.006*"喜欢"'), (2, '0.009*"甜品" + 0.008*"双皮奶" + 0.007*"广州" + 0.006*"这里" + 0.005*"招牌" + 0.005*"手面" + 0.005*"三星" + 0.005*"生意" + 0.005*"云吞" + 0.005*"上海"'), (3, '0.014*"双皮奶" + 0.008*"不是" + 0.008*"真的" + 0.008*"南信" + 0.007*"一起" + 0.007*"红豆" + 0.007*"广州" + 0.006*"我们" + 0.005*"自己" + 0.005*"特别"'), (4, '0.014*"双皮奶" + 0.013*"甜品" + 0.008*"椰汁" + 0.008*"上下" + 0.007*"甘露" + 0.007*"杨枝" + 0.007*"好吃" + 0.007*"有点" + 0.006*"红豆" + 0.006*"广州"'), (5, '0.029*"双皮奶" + 0.012*"广州" + 0.012*"甜品" + 0.009*"真的" + 0.008*"没有" + 0.008*"好吃" + 0.007*"一份" + 0.007*"感觉" + 0.007*"味道" + 0.006*"觉得"'), (6, '0.012*"双皮奶" + 0.007*"三星" + 0.006*"上下" + 0.006*"甜品" + 0.005*"最后" + 0.005*"真的" + 0.005*"姜撞奶" + 0.005*"广州" + 0.005*"南信" + 0.005*"步行街"'), (7, '0.008*"芝麻糊" + 0.008*"楼下" + 0.00
# ...
