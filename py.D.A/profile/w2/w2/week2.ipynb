# %%
animals = 'cat'
print(f'My hovercraft is full of {animals!r}.')
print(f'My hovercraft is full of {animals:>8}.')
# Out:
# My hovercraft is full of 'cat'.
# My hovercraft is full of      cat.

# %%
with open('jdemo.py') as f:
    for line in f:
        if line.startswith('import'):
            print('found a package')
# Out:
# found a package
# found a package
# found a package

# %%
import os
age = int(input("请输入你的年龄:"))
print(f'你的年龄是{age:9}')
lstr = input("请输入小数，用,隔开:")
l = [float(x) for x in lstr.split(",")]
l.sort()
print(l)
code = input("请输入指令:")
result = eval(code) #注意，这样容易被输入代码来攻击
print(result)
# Out:
# 你的年龄是       20
# [3.4, 5.6, 6.0, 7.8, 8.9, 12.3]
# Traceback (most recent call last):
#
#   File ~/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[3], line 9
#     result = eval(code) #注意，这样容易被输入代码来攻击
#
#   File <string>:1
#     'test
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
import jieba
print(list(jieba.cut("我来到北京航空航天大学")))
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/ph/_d4w3ksn4qz0n0m97pvp4g2c0000gn/T/jieba.cache
# Loading model cost 0.284 seconds.
# Prefix dict has been built successfully.
# ['我', '来到', '北京航空航天大学']

# %%
import jieba
import jieba.posseg as pseg
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

doc = '今天这一件是我们家的爆款爆款爆款爆款爆款'
#C:\Windows\Fonts\simfang.ttf # for windows
fpath = 'STHeiti Light.ttc'

terms = jieba.cut(doc)
terms = list(terms)
tfreq = Counter(terms)
for term in tfreq:
	print(f'{term}\t{tfreq[term]}')

wd = WordCloud(font_path=fpath)
wd.fit_words(tfreq)
#wd.to_file('./wd.png')
plt.imshow(wd)
plt.axis('off')
plt.show()
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/ph/_d4w3ksn4qz0n0m97pvp4g2c0000gn/T/jieba.cache
# Loading model cost 0.307 seconds.
# Prefix dict has been built successfully.
# 今天	1
# 这	1
# 一件	1
# 是	1
# 我们	1
# 家	1
# 的	1
# 爆款	5
